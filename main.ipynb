# %%
# %pip install geoai-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.0/281.0 kB 17.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.9/632.9 kB 38.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.5/122.5 kB 8.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 59.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 25.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 67.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 74.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.8/241.8 kB 12.2 MB/s eta 0:00:00
# ...

# %%
# %pip install --upgrade leafmap

# %%
import geoai

# %% [markdown]
# <h3>Importer les données</h3>

# %%
# Example for Sentinel-2 item
item_url = "https://planetarycomputer.microsoft.com/api/stac/v1/collections/sentinel-2-l2a/items/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633"

# %%
# Specify which bands to download (Sentinel-2 bands)
bands_to_download = [
    "B01",
    "B02",
    "B03",
    "B04",
    "B05",
    "B06",
    "B07",
    "B08",
    "B8A",
    "B09",
    "B11",
    "B12",
    "AOT",
    "WVP",
    "SCL",
]

# %% [markdown]
# <!DOCTYPE html>
# <html lang="fr">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Résumé des bandes Sentinel-2</title>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       background-color: #f8fafc;
#       color: #0f172a;
#       padding: 20px;
#     }
#     h1 {
#       text-align: center;
#       color: #1e40af;
#     }
#     table {
#       width: 100%;
#       border-collapse: collapse;
#       margin-top: 20px;
#       background: #fff;
#       border-radius: 8px;
#       overflow: hidden;
#       box-shadow: 0 6px 15px rgba(0,0,0,0.08);
#     }
#     th, td {
#       padding: 12px 15px;
#       text-align: left;
#       border-bottom: 1px solid #e2e8f0;
#     }
#     th {
#       background-color: #e0e7ff;
#       font-weight: bold;
#     }
#     tr:hover {
#       background-color: #f1f5f9;
#     }
#     caption {
#       caption-side: top;
#       font-size: 1.2em;
#       font-weight: bold;
#       padding: 10px 0;
#       color: #1e3a8a;
#     }
#   </style>
# </head>
# <body>
#   <h1>Résumé global des bandes Sentinel-2</h1>
#   <table>
#     <caption>Bandes et leurs utilisations principales</caption>
#     <thead>
#       <tr>
#         <th>Band</th>
#         <th>Nom / Spectre</th>
#         <th>Résolution</th>
#         <th>Utilisation principale</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td>B1</td>
#         <td>Côtière</td>
#         <td>60 m</td>
#         <td>Correction atmosphérique, zones côtières</td>
#       </tr>
#       <tr>
#         <td>B2</td>
#         <td>Bleu</td>
#         <td>10 m</td>
#         <td>Eau claire, atmosphère, correction</td>
#       </tr>
#       <tr>
#         <td>B3</td>
#         <td>Vert</td>
#         <td>10 m</td>
#         <td>Végétation, zones humides, couleur naturelle</td>
#       </tr>
#       <tr>
#         <td>B4</td>
#         <td>Rouge</td>
#         <td>10 m</td>
#         <td>Végétation, calcul NDVI, classification générale</td>
#       </tr>
#       <tr>
#         <td>B5</td>
#         <td>Red Edge 1</td>
#         <td>20 m</td>
#         <td>Santé et stress végétal</td>
#       </tr>
#       <tr>
#         <td>B6</td>
#         <td>Red Edge 2</td>
#         <td>20 m</td>
#         <td>Santé et stress végétal</td>
#       </tr>
#       <tr>
#         <td>B7</td>
#         <td>Red Edge 3</td>
#         <td>20 m</td>
#         <td>Stress végétal et agriculture de précision</td>
#       </tr>
#       <tr>
#         <td>B8</td>
#         <td>NIR (Proche infrarouge)</td>
#         <td>10 m</td>
#         <td>Végétation, NDVI, biomasse</td>
#       </tr>
#       <tr>
#         <td>B8A</td>
#         <td>NIR étroit</td>
#         <td>20 m</td>
#         <td>Analyse fine de la végétation</td>
#       </tr>
#       <tr>
#         <td>B9</td>
#         <td>Vapeur d'eau</td>
#         <td>60 m</td>
#         <td>Correction atmosphérique (vapeur d’eau)</td>
#       </tr>
#       <tr>
#         <td>B10</td>
#         <td>Cirrus</td>
#         <td>60 m</td>
#         <td>Détection des nuages cirrus</td>
#       </tr>
#       <tr>
#         <td>B11</td>
#         <td>SWIR 1</td>
#         <td>20 m</td>
#         <td>Humidité du sol, brûlis, sols secs</td>
#       </tr>
#       <tr>
#         <td>B12</td>
#         <td>SWIR 2</td>
#         <td>20 m</td>
#         <td>Détection de feu, sols secs, minéralogie</td>
#       </tr>
#     </tbody>
#   </table>
# </body>
# </html>

# %%
# Create a directory for the downloaded bands
output_directory = "sentinel2_bands"

# %%
# Download the bands, save them to the output directory, and create a merged GeoTIFF.
# The download process may take a while. Please be patient.
downloaded_bands = geoai.download_pc_stac_item(
    item_url=item_url,
    bands=bands_to_download,
    output_dir=output_directory,
    show_progress=True,
    merge_bands=True,
    merged_filename="sentinel2_all_bands.tif",
    overwrite=False,  # Skip files that already exist
    cell_size=10,  # Resample all bands to 10m resolution
)
# Out:
# ...
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B01.tif already exists, skipping (use overwrite=True to force download).
# ...
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B02.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B03.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B04.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B05.tif already exists, skipping (use overwrite=True to force download).
# File sentinel2_bands/S2B_MSIL2A_20250228T173149_R055_T14SLH_20250228T212633_B06.tif already exists, skipping (use overwrite=True to force download).
# ...

# %%
# Print the paths to the downloaded files
for band, path in downloaded_bands.items():
    print(f"Downloaded {band}: {path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1181891412.py in <cell line: 0>()
#       1 # Print the paths to the downloaded files
# ----> 2 for band, path in downloaded_bands.items():
#       3     print(f"Downloaded {band}: {path}")
#
# NameError: name 'downloaded_bands' is not defined
